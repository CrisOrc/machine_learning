# %% [markdown]
# # **Naive Bayes Classifier**

# %% [markdown]
# ```Iris``` dataset description [here](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html#sklearn.datasets.load_iris) \
# ```GaussianNB``` documentation [here](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html#sklearn.naive_bayes.GaussianNB)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier as kNN
from sklearn.datasets import load_iris # Iris dataset

# %%
iris = load_iris()
iris_x = iris.data[:, 0:2]
iris_y = iris.target

print (iris_x.shape, iris_y.shape)
# Out:
# (150, 2) (150,)

# %%
# Instance kNN object
naive_bayes = GaussianNB()

# Training
naive_bayes.fit( iris_x , iris_y )
# Out:
# SVC(kernel='linear')

# %%
def plot_predict_model(model, data_x, data_y, offset=0.5, n_neighbors=1 ):

  h_min, h_max = min(data_x[:, 0]) - offset, max(data_x[:, 0]) + offset
  v_min, v_max = min(data_x[:, 1]) - offset, max(data_x[:, 1]) + offset

  h_grid, v_grid = np.meshgrid(np.linspace(h_min, h_max, 100), np.linspace(v_min, v_max, 100))

#Conditional predict model
  #Type model Naive Bayes
  if model == 'naive_bayes':
    naive_bayes=GaussianNB()
    naive_bayes.fit(data_x, data_y)
    pred_grid = naive_bayes.predict(np.c_[h_grid.ravel(), v_grid.ravel()])

  #Type model KNN
  if model == 'knn':
    n_neighbors = n_neighbors
    knn = kNN(n_neighbors = n_neighbors , metric = "euclidean")
    knn.fit(data_x, data_y)
    pred_grid = knn.predict(np.c_[h_grid.ravel(), v_grid.ravel()])

  #Type model SVM
  if model == 'svm':
    clf = SVC(kernel = 'linear')
    clf.fit(data_x, data_y)
    #pred_grid = clf.predict(np.c_[h_grid.ravel(), v_grid.ravel()])
    pred_grid = clf.decision_function(np.c_[h_grid.ravel(), v_grid.ravel()])

  pred_grid = pred_grid.reshape(h_grid.shape)

  _, ax = plt.subplots(figsize=(5,4))

#Conditional to type graphics
  if model == 'svm':
    ax.contour(h_grid, v_grid, pred_grid, colors='k', levels=[-1, 0, 1], alpha=0.5, linestyles=['--', '-', '--'])
    ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=100, linewidth=1, facecolors='none', edgecolors='k')
    pred_grid = clf.predict(np.c_[h_grid.ravel(), v_grid.ravel()])
    pred_grid = pred_grid.reshape(h_grid.shape)

  #Graphic background color
  ax.pcolormesh(h_grid, v_grid, pred_grid, cmap='Paired')
  ax.scatter(data_x[:, 0], data_x[:, 1], c=data_y, edgecolors='k', cmap='Paired')

  ax.set_xticks(())
  ax.set_yticks(())

  plt.tight_layout()

# %%
#Show graphig
plot_predict_model('knn', iris_x, iris_y)

# %% [markdown]
# ## On real data - Fruits dataset
#
# Download the fruits data [here](https://drive.google.com/file/d/1M8tiAWDZclABJN1Meq9oEHCLJTNyHdpP/view?usp=share_link)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB

# %%
fruit_data = _ # Load the fruits dataset
fruits_x = _  # Features. We'll pick 2
fruits_y = _  # Labels

# Convert everything to a np array
fruits_x, fruits_y = np.asarray(fruits_x), np.asarray(fruits_y)

# Print shapes
print ( _ )

# %%
# Instance GaussianNB object
naive_bayes = GaussianNB()

# Training
 _ #(num_samples, Features)

# %%
## Plot decision boundaries
_
